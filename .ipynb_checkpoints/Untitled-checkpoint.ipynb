# %%
import pandas as pd
import numpy as np
import re

# %%
contracts_path = "contracts.csv"
details_path   = "contract_details.csv"

df_contracts = pd.read_csv(contracts_path)
df_details   = pd.read_csv(details_path)

print("contracts:", contracts.shape)
print("details:", details.shape)

contracts.head()
# Out:
# contracts: (1542, 8)
# details: (1542, 50)
#    sl_no                                    pe_name  \
# 0      1                LALJHADI RURAL MUNICIPALITY
# 1      2        Bharatpur Metropolitian City Office
# 2      3        Bharatpur Metropolitian City Office
# 3      4  Infrastructure Development Office Chitwan
# 4      5  Infrastructure Development Office Chitwan
#
#                                        contract_name  contract_amount  \
# 0       Construction of Shankarpur Hospital Building      60502650.12
# 1  Road Construction at different wards of Bharat...      35000000.00
# 2  Blacktopped Road Construction from Mitralal Ad...       4501900.14
# 3      Construction/Upgrading works Under Package-05       3657654.18
# 4  Construction/Upgrading works of  Pandechowk - ...       2053840.40
#
#   procurement_category procurement_method       status  \
# 0                Works                NCB  In-Progress
# 1                Works                NCB    Completed
# 2                Works                NCB    Completed
# 3                Works                NCB  In-Progress
# 4                Works                NCB  In-Progress
#
#                contract_code
# 0            LAL-14-2077/078
# 1   30-BMC/2078/079/W/NCB/88
# 2  42-BMC/2078/079/W/NCB/123
# 3    IDO/CHT/W/NCB/05/078-79
# 4    IDO/CHT/W/NCB/07/078-79

# %%
merged_df = pd.merge(
    df_contracts,
    df_details,
    left_on='contract_code',
    right_on='contract_id',
    how='inner' # Used inner merge since both files have the same number of rows
)

# %%
# --- 3. Clean Column Names (Remove Prefix) ---
# Identify columns with the prefix 'contractRecordsTO.' and rename them
prefix = 'contractRecordsTO.'
columns_to_rename = {
    col: col.replace(prefix, '')
    for col in merged_df.columns
    if prefix in col
}
merged_df.rename(columns=columns_to_rename, inplace=True)

# %%
columns_to_drop = [
    'contractName',          # Duplicate of 'contract_name'
    'contractAmount',        # Duplicate of 'contract_amount'
    'procurementCategoryId', # Duplicate of 'procurement_category'
    'procurementMethodId',   # Duplicate of 'procurement_method'
    'contractStatus',        # Duplicate of 'status'
    'contractId'             # Duplicate of 'contract_code'
]

# %%
merged_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# --- 5. Save the Final Cleaned Data ---
cleaned_file_name = 'combined_contract_data.csv'
merged_df.to_csv(cleaned_file_name, index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cleaned_file_name.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
# Out:
# Index(['sl_no', 'pe_name', 'contract_name', 'contract_amount',
#        'procurement_category', 'procurement_method', 'status', 'contract_code',
#        'contractrecordsto_scptype', 'contractrecordsto_beneficialowner',
#        'contractrecordsto_biddingprocess', 'contractrecordsto_bolpatraid1',
#        'contractrecordsto_bolpatraid2', 'contractrecordsto_bolpatraid3',
#        'contractrecordsto_contractaddress'],
#       dtype='object')

# %%
# Out:
#    sl_no                                    pe_name  \
# 0      1                LALJHADI RURAL MUNICIPALITY
# 1      2        Bharatpur Metropolitian City Office
# 2      3        Bharatpur Metropolitian City Office
# 3      4  Infrastructure Development Office Chitwan
# 4      5  Infrastructure Development Office Chitwan
#
#                                        contract_name  contract_amount  \
# 0       Construction of Shankarpur Hospital Building      60502650.12
# 1  Road Construction at different wards of Bharat...      35000000.00
# 2  Blacktopped Road Construction from Mitralal Ad...       4501900.14
# 3      Construction/Upgrading works Under Package-05       3657654.18
# 4  Construction/Upgrading works of  Pandechowk - ...       2053840.40
#
#   procurement_category procurement_method       status  \
# 0                Works                NCB  In-Progress
# 1                Works                NCB    Completed
# 2                Works                NCB    Completed
# 3                Works                NCB  In-Progress
# 4                Works                NCB  In-Progress
#
#                contract_code contractrecordsto_scptype  \
# 0            LAL-14-2077/078                      <NA>
# 1   30-BMC/2078/079/W/NCB/88                      <NA>
# 2  42-BMC/2078/079/W/NCB/123                      <NA>
# 3    IDO/CHT/W/NCB/05/078-79                      <NA>
# 4    IDO/CHT/W/NCB/07/078-79                      <NA>
#
#   contractrecordsto_beneficialowner  ... contractrecordsto_sharedpercentage2  \
# 0                              <NA>  ...                                  30
# 1                              <NA>  ...                                <NA>
# 2                              <NA>  ...                                <NA>
# 3                              <NA>  ...                                <NA>
# 4                              <NA>  ...                                <NA>
#
#   contractrecordsto_sharedpercentage3 contractrecordsto_sourceoffund  \
# 0                                  30     --Select source of Fund --
# 1                                <NA>              Internal Resource
# 2                                <NA>              Internal Resource
# 3                                <NA>                      Goverment
# 4                                <NA>                      Goverment
#
#   contractrecordsto_startdate contractrecordsto_totalpayment  \
# 0                  07-06-2021                     17000000.0
# 1                  15-05-2022                      1600000.0
# 2                  20-07-2022                            0.0
# 3                        <NA>                            0.0
# 4                        <NA>                            0.0
#
#    contractrecordsto_vat_no1 contractrecordsto_vat_no2  \
# 0                  301250032               300130805.0
# 1                  605970487                       NaN
# 2                  302695005                       NaN
# 3                  602253303                       NaN
# 4                  602253303                       NaN
#
#   contractrecordsto_vat_no3 contractrecordsto_warrantyperiod  \
# 0               300132335.0                                0
# 1                       NaN                                0
# 2                       NaN                                0
# 3                       NaN                                0
# 4                       NaN                                0
#
#                  contract_id
# 0            LAL-14-2077/078
# 1   30-BMC/2078/079/W/NCB/88
# 2  42-BMC/2078/079/W/NCB/123
# 3    IDO/CHT/W/NCB/05/078-79
# 4    IDO/CHT/W/NCB/07/078-79
#
# [5 rows x 58 columns]

# %%
# Out:
#    contract_amount  contractrecordsto_contractamount  \
# 0      60502650.12                       60502650.12
# 1      35000000.00                       35000000.00
# 2       4501900.14                        4501900.14
# 3       3657654.18                        3657654.18
# 4       2053840.40                        2053840.40
#
#    contractrecordsto_estimatedcost  contractrecordsto_outstandingvalue  \
# 0                     1.000000e+08                         17000000.00
# 1                     4.500000e+07                                0.00
# 2                     5.001357e+06                                0.00
# 3                     4.498350e+06                          3657654.18
# 4                     2.996418e+06                          2053840.40
#
#    contractrecordsto_totalpayment
# 0                      17000000.0
# 1                       1600000.0
# 2                             0.0
# 3                             0.0
# 4                             0.0

# %%
# Out:
#   contractrecordsto_contractdate contractrecordsto_deliverydate  \
# 0                     2021-06-07                            NaT
# 1                     2022-05-10                            NaT
# 2                     2022-07-20                            NaT
# 3                     2021-11-26                            NaT
# 4                     2021-11-26                            NaT
#
#   contractrecordsto_dlpenddate contractrecordsto_dlpstartdate  \
# 0                   2024-07-07                     2023-07-06
# 1                          NaT                            NaT
# 2                          NaT                            NaT
# 3                          NaT                            NaT
# 4                          NaT                            NaT
#
#   contractrecordsto_endorcompletedate contractrecordsto_postvalidationdate  \
# 0                          2023-07-06                                  NaT
# 1                          2022-10-02                                  NaT
# 2                          2022-12-19                                  NaT
# 3                                 NaT                                  NaT
# 4                                 NaT                                  NaT
#
#   contractrecordsto_startdate
# 0                  2021-06-07
# 1                  2022-05-15
# 2                  2022-07-20
# 3                         NaT
# 4                         NaT

# %%
# Out:
# Dropping 6 columns
# (1542, 52)

# %%
# Out:
#                contract_code  contract_duration_days  payment_ratio
# 0            LAL-14-2077/078                   759.0       0.280979
# 1   30-BMC/2078/079/W/NCB/88                   140.0       0.045714
# 2  42-BMC/2078/079/W/NCB/123                   152.0       0.000000
# 3    IDO/CHT/W/NCB/05/078-79                     NaN       0.000000
# 4    IDO/CHT/W/NCB/07/078-79                     NaN       0.000000

# %%
# Out:
# 'contracts_combined_cleaned.csv'
